# %% [markdown]
# # How Does A Country's GDP and Emmissons profile relate to it's average annual temperature?
#
# ## Project 1

# %% [markdown]
# ### Introduction

# %% [markdown]
# The purpose of this study is to set up a framework for observing the relationship between a Country's average annual temperature (the dependent variable) and its GDP and annual emissions (the independent variables). For the sake of clarity, Canada will be used as an example in the Figures and Graphs portion of the study, however, any country in the sample could be used.
#
# Two datasets were combined to form the primary dataset in this study:  "Climate Change: Earth Surface Temperature Data" (from https://www.kaggle.com/datasets/berkeleyearth/climate-change-earth-surface-temperature-data) and Our World in Data CO2 and Greenhouse Gas Emissions database (from https://ourworldindata.org/co2-emissions). The sample from Kaggle includes a number of datasets, however, for the purpose of this study only the "Global Land Temperature By Country" data was used. This dataset includes the average monthly temperature for 243 countries from 1744-2013. The Our World in Data (OWID) sample contains data on annual co2, methane and nitrous oxide emissions, as well as annual GDP by country from 1990-2018.
#
# Findings from the study include a potential weak positive correlation between Canada's Average Temperature and both GDP and Co2 emissions.

# %% [markdown]
# ### Data Cleaning/Loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from datetime import datetime
GLT_City_URL = "C:\\Users\\micha\\OneDrive\\Michael\\UofT Year 4\\ECO225 - Big Data Tools for Economists\\Project Data\\archive\\GlobalLandTemperaturesByCountry.csv"
Emmisions_URL = "C:\\Users\\micha\\OneDrive\\Michael\\UofT Year 4\\ECO225 - Big Data Tools for Economists\\Project Data\\data.csv"

# %%
#GLT -> Global Land Temperature dataset from Kaggle
#E -> Emmissons dataset from OWID
GLT = pd.read_csv(GLT_City_URL).drop(labels = 'AverageTemperatureUncertainty', axis = 1)
E = pd.read_csv(Emmisions_URL)
E
# Out:
#           country  year           gdp  cement_co2     co2  coal_co2  gas_co2  \
# 0     Afghanistan  1990  1.306598e+10       0.046   2.024     0.278    0.403
# 1     Afghanistan  1991  1.204736e+10       0.046   1.914     0.250    0.389
# 2     Afghanistan  1992  1.267754e+10       0.046   1.482     0.022    0.363
# 3     Afghanistan  1993  9.834581e+09       0.047   1.487     0.018    0.352
# 4     Afghanistan  1994  7.919857e+09       0.047   1.454     0.015    0.338
# ...           ...   ...           ...         ...     ...       ...      ...
# 4668     Zimbabwe  2014  2.122250e+10       0.496  11.946     7.732    0.000
# 4669     Zimbabwe  2015  2.102745e+10       0.585  12.255     8.061    0.000
# 4670     Zimbabwe  2016  2.096179e+10       0.461  10.533     6.932    0.000
# 4671     Zimbabwe  2017  2.194784e+10       0.469   9.596     5.900    0.000
# 4672     Zimbabwe  2018  2.271535e+10       0.558  11.795     7.178    0.000
#
#       methane  nitrous_oxide  oil_co2
# 0        6.74           2.84    1.271
# 1        7.02           2.93    1.204
# 2        7.13           2.89    1.030
# 3        7.21           2.93    1.048
# 4        7.47           2.76    1.032
# ...       ...            ...      ...
# 4668    11.45           4.99    3.718
# 4669    12.40           5.55    3.609
# 4670    11.98           5.10    3.140
# 4671    12.12           5.24    3.227
# 4672    12.44           5.43    4.060
#
# [4673 rows x 10 columns]

# %% [markdown]
# These are some of the rows in the OWID dataset. All values are annual figures and the date range is 1990-2018

# %%
GLT
# Out:
#                 dt  AverageTemperature   Country
# 0       1743-11-01               4.384     Åland
# 1       1743-12-01                 NaN     Åland
# 2       1744-01-01                 NaN     Åland
# 3       1744-02-01                 NaN     Åland
# 4       1744-03-01                 NaN     Åland
# ...            ...                 ...       ...
# 577457  2013-05-01              19.059  Zimbabwe
# 577458  2013-06-01              17.613  Zimbabwe
# 577459  2013-07-01              17.000  Zimbabwe
# 577460  2013-08-01              19.759  Zimbabwe
# 577461  2013-09-01                 NaN  Zimbabwe
#
# [577462 rows x 3 columns]

# %% [markdown]
# These are some of the rows in the Kaggle Dataset. Dates are reported monthly, starting in November 1743 and going up to September 2013. There are lots of missing values.

# %% [markdown]
# **Combing the datasets:** To combine these two data sets, several operations must be performed:
#
# Missing values need to be dropped, column titles names must use the same naming convention to be merged and the final dataset should contain only matching data from shared time-frames.

# %%
#Fixiing column names and dropping missing values
E.rename(columns = {'country':'Country', 'year':'Year'}, inplace = True)
GLT.rename(columns = {'dt':'Year'}, inplace = True)
GLT = GLT.dropna() 
#Generalize monthly inputs by year for merging
GLT['Year'] = GLT['Year'].str[0:4].astype(int)

# %%
#Merging data
data = E.merge(GLT, on=['Country','Year'])

# %%
data.loc[0:15]
# Out:
#         Country  Year           gdp  cement_co2    co2  coal_co2  gas_co2  \
# 0   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 1   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 2   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 3   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 4   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 5   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 6   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 7   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 8   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 9   Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 10  Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 11  Afghanistan  1990  1.306598e+10       0.046  2.024     0.278    0.403
# 12  Afghanistan  1991  1.204736e+10       0.046  1.914     0.250    0.389
# 13  Afghanistan  1991  1.204736e+10       0.046  1.914     0.250    0.389
# 14  Afghanistan  1991  1.204736e+10       0.046  1.914     0.250    0.389
# 15  Afghanistan  1991  1.204736e+10       0.046  1.914     0.250    0.389
#
#     methane  nitrous_oxide  oil_co2  AverageTemperature
# 0      6.74           2.84    1.271               1.558
# 1      6.74           2.84    1.271               3.669
# 2      6.74           2.84    1.271               8.402
# 3      6.74           2.84    1.271              14.457
# 4      6.74           2.84    1.271              22.442
# 5      6.74           2.84    1.271              26.340
# 6      6.74           2.84    1.271              27.526
# 7      6.74           2.84    1.271              26.563
# 8      6.74           2.84    1.271              22.217
# 9      6.74           2.84    1.271              14.530
# 10     6.74           2.84    1.271              10.042
# 11     6.74           2.84    1.271               2.174
# 12     7.02           2.93    1.204               1.168
# 13     7.02           2.93    1.204               2.352
# 14     7.02           2.93    1.204               7.925
# 15     7.02           2.93    1.204              14.645

# %% [markdown]
# **Important note**: The final dataset contains 12 average temperature datapoints for each country. 1 for each month (see 'Year' from row 0-11 and then 12 onward)

# %% [markdown]
# ### Summary Statistics Tables

# %%
sum_stats = data.describe()
sum_stats
# Out:
#                Year           gdp    cement_co2           co2      coal_co2  \
# count  42872.000000  4.287200e+04  41792.000000  42872.000000  42860.000000
# mean    2001.346800  4.292923e+11      5.762976    173.374584     69.263352
# std        6.833774  1.389447e+12     33.795367    679.985834    392.231972
# min     1990.000000  2.757300e+08      0.000000      0.000000      0.000000
# 25%     1995.000000  1.638350e+10      0.114000      2.841000      0.000000
# 50%     2001.000000  5.176666e+10      0.621000     17.380000      0.442000
# 75%     2007.000000  2.636860e+11      2.778000     78.807000     13.723000
# max     2013.000000  1.610840e+13    748.323000   9956.309000   7493.454000
#
#             gas_co2       methane  nitrous_oxide       oil_co2  \
# count  42860.000000  42872.000000   42872.000000  42860.000000
# mean      32.678576     45.858905      16.406536     62.326269
# std      119.676389    117.162798      44.170490    216.884221
# min        0.000000      0.040000       0.000000      0.059000
# 25%        0.000000      4.200000       1.420000      1.891000
# 50%        1.742000     11.300000       4.690000      8.922000
# 75%       18.903000     35.180000      13.540000     36.397000
# max     1410.367000   1147.210000     522.800000   2644.237000
#
#        AverageTemperature
# count        42872.000000
# mean            18.716288
# std             10.522285
# min            -34.665000
# 25%             12.771750
# 50%             22.225500
# 75%             26.284000
# max             38.842000

# %% [markdown]
# #### **Explanation:** Interpreting Summary Statistics
#
# **Average Temperature - Dependent Variable:** From this table we can observe the total range of average monthly temperatures taken in every country in the dataset from 1990-2013. The lowest recorded temperature in the dataset is -34.6 degrees Celsius and the highest is 38.8 degrees Celsius. The mean is 18.71 degrees Celsius. This particular snapshot of the data doesn't tell us too much as countries in Northern Europe are expected to have drastically different average temperatures from countries in Central Africa for example. Furthermore, without the time trend, we cannot study how temperatures changed, whether they increased or decreased, and by how much. To observe relevant relationships, we must perform a study on a per country basis.
#
# **Year - Independent Variable:** Min & Max represent the range of years in the final dataset.
#
# **GDP - Independent Variable:** The summary statistics for GDP gives us a bit more information than Average Temperature. This is because we can observe the range of economic output of countries in our dataset in Real USD in 2011 dollars (see documentation for OWID dataset). The lowest recorded annual GDP is ~276 Million and the highest recorded GDP is ~16.1 Trillion. The mean level of GDP ~429 Million but standard deviation is ~1.4 Trillion so there is a high degree of variance in the sample.
#
# **Emissions - Independent Variable:** For all emissions in the sample data, the lowest recorded emission per country per year is approx 0, meaning that some countries in the sample emitted no greenhouse gasses in any form in a given year. The mean for each demonstrates the average annual emission of countries in this dataset between 1990-2013 in Tons. We can observe from this table that Co2 takes the majority share of greenhouse gas emissions, and, amongst C02 emissions, coal is the highest contributor.

# %% [markdown]
# ### Figures and Graphs

# %% [markdown]
# For the sake of clarity, the figures featured below will only highlight a subset of the data featuring Canada. Due to the nature and size of the GLT dataset, annual average temperature can only be calculated for each country one at a time. Thus, the calculation is done below and not in the Data Cleaning portion of this study.

# %%
def average(lst):
    return sum(lst)/len(lst)
#dcy -> Data, Country, Years
dcy = data.groupby(['Country','Year'])
Canada_Annual_Temp = []
for year in Canada_years:
    Canada_Annual_Temp.append(average(dcy.get_group(('Canada', year))['AverageTemperature']))

# %%
Canada_co2 = data_country.get_group('Canada')['co2']
plt.scatter(Canada_Annual_Temp, Canada_co2)
# set axis lables
plt.xlabel("Average Annual Temperature")
plt.ylabel("Co2 Emissions in Tons")
# set chart title
plt.title("Average Temperature vs Co2 Emissions in Canada")
plt.show()

# %% [markdown]
# The figure above shows how average annual temperatures in Canada change in accordance with Co2 Emissions. There might be a weak positive correlation between temperature and Canadian Co2 emissions, but from this graph we cannot infer strong correlation or causation. This makes sense as a country's greenhouse gas emissions should contribute to overall global warming, but it's not clear that a countries individual emissions will directly affect it's local temperature.

# %%
Canada_gdp = data_country.get_group('Canada')['gdp']
plt.scatter(Canada_Annual_Temp, Canada_gdp)
# set axis lables
plt.xlabel("Average Annual Temperature")
plt.ylabel("Annual GDP in Trillions of USD")
# set chart title
plt.title("Average Temperature vs GDP")
plt.show()

# %% [markdown]
# The figure above shows a positive correlation between Canada's GDP and its average annual temperature. In general, we can infer from this figure that the higher the annual GDP, the higher the annual average temperature. This is not a casual relationship, however, as both GDP and Average Annual Temperature seem to increase with time.

# %%
data_country = data.groupby('Country')
Canada_years = data_country.get_group('Canada')['Year']
plt.scatter(Canada_Annual_Temp, Canada_years)
# set axis lables
plt.xlabel("Average Annual Temperature")
plt.ylabel("Year")
# set chart title
plt.title("Temperature change over time in Canada")
plt.show()

# %% [markdown]
# This graph demonstrates a positive correlation between time and average annual temperatures. This means that over time, the land temperature in Canada is increasing, supporting the overall Global Warming research in the literature.

# %%
plt.scatter(Canada_co2, Canada_years)
# set axis lables
plt.xlabel("Annual Co2 Emmissions in Tons")
plt.ylabel("Year")
# set chart title
plt.title("Change in Co2 emmission over time in Canada")
plt.show()

# %%
Canada_co2.max()
# Out:
# 593.516

# %% [markdown]
# The Figure above demonstrates clearly that Co2 emissions in Canada have been increasing over time. There have been a slight reduction in emissions from around 2002 onwards, and the maximum annual Co2 emission was in around 2006 and was approx 593.5 tons of Co2.

# %%
plt.scatter(Canada_gdp, Canada_years)
# set axis lables
plt.xlabel("Annual Real GDP in Trillions of USD")
plt.ylabel("Year")
# set chart title
plt.title("Change in GDP over time in Canada")
plt.show()

# %% [markdown]
# This final graph clearly shows that GDP has been increasing in Canada over time. This supports the insight that Temperature and GDP don't have a casual relationship because both GDP and Temperature seem to increase with time.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# By combing the Kaggle data and the OWID data, a new dataset was created that contains 151 countries and their corresponding monthly average temperature, annual GDP and Emissions from 1990 to 2013. With this new dataset, a large number of graphs could be created to illustrate different relationships between variables within the sample.
#
# In this study, the relationship between Canadian annual average temperatures, GDP and Emissions were plotted in scatterplot graphs to illustrate the general relationship between the dependent variable (temperature) and a number of independent variables. A strong positive relationship between annual average temperature and GDP, and a weak positive relationship between annual average temperature and Co2 was observed. These insights make intuitive sense because annual average temperatures seem to be increasing over time, as do both Co2 and GDP in Canada.
